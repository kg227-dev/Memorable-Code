# %%
#!/usr/bin/env python
# coding: utf-8

# In[3]:


import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn import linear_model
from statsmodels.api import OLS
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso


dataset = pd.read_csv('ff_data2019.csv')
print(dataset.shape)
print(dataset.describe())

#dataset.isnull().any()
#dataset = dataset.fillna(method='ffill')
#l_owners_17

vals = ["l_project", "l_actual", "I_passydpg","I_passtdpg","I_passintpg","I_rushydpg","I_rushtdpg","l_rush1stpg","l_receptspg","l_recydspg","l_rectdpg", "l_rec1stpg"]
 





X = dataset[vals].values
y = dataset['l_points'].values
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset['l_points'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)







print("Lasso Predict with transformations")
clf = linear_model.Lasso(alpha=2)


clf.fit(X_train, y_train)
coeff_df1=pd.DataFrame(clf.coef_)
print(coeff_df1)
print(clf.intercept_)
y_pred = clf.predict(X_test)

dfLasso = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(dfLasso)
 
dfLasso.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))



print(OLS(y_train,X_train).fit().summary())
# Out:
# (325, 33)
#              l_gp    l_points    l_owners   l_project    l_actual  \
# count  325.000000  325.000000  325.000000  325.000000  325.000000
# mean     4.504615   48.585692    0.395815  207.538462  199.046154
# std      0.925034   33.725980    0.403750  130.033101  117.104737
# min      1.000000    9.670000    0.000000    1.000000    2.000000
# 25%      4.000000   20.000000    0.010000   87.000000   92.000000
# 50%      5.000000   39.000000    0.190000  206.000000  202.000000
# 75%      5.000000   70.670000    0.860000  318.000000  305.000000
# max      6.000000  178.300000    1.000000  482.000000  388.000000
#
#          l_passyds    l_passtd   l_passint   l_rushyds    l_rushtd  ...  \
# count   325.000000  325.000000  325.000000  325.000000  325.000000  ...
# mean    122.763077    0.738462    0.356923   53.375385    0.424615  ...
# std     367.819630    2.358835    1.220449  105.010291    1.079270  ...
# min       0.000000    0.000000    0.000000   -8.000000    0.000000  ...
# 25%       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 50%       0.000000    0.000000    0.000000    2.000000    0.000000  ...
# 75%       0.000000    0.000000    0.000000   52.000000    0.000000  ...
# max    1831.000000   12.000000    8.000000  587.000000    8.000000  ...
#
#        I_passydpg  I_passtdpg  I_passintpg  I_rushydpg  I_rushtdpg  \
# count  325.000000  325.000000   325.000000  325.000000  325.000000
# mean    28.197692    0.164205     0.083026   11.563128    0.092462
# std     79.770092    0.502336     0.271995   22.010239    0.240128
# min      0.000000    0.000000     0.000000   -1.600000    0.000000
# 25%      0.000000    0.000000     0.000000    0.000000    0.000000
# 50%      0.000000    0.000000     0.000000    0.500000    0.000000
# 75%      0.000000    0.000000     0.000000   11.000000    0.000000
# max    366.200000    2.400000     1.600000  117.400000    2.000000
#
#        l_rush1stpg  l_receptspg  l_recydspg   l_rectdpg  l_rec1stpg
# count   325.000000   325.000000  325.000000  325.000000  325.000000
# mean      0.620359     2.322308   26.733641    0.168103    1.257282
# std       1.147708     1.952554   25.473625    0.249092    1.244974
# min       0.000000     0.000000   -1.400000    0.000000    0.000000
# 25%       0.000000     1.000000    7.250000    0.000000    0.200000
# 50%       0.000000     1.800000   18.500000    0.000000    0.800000
# 75%       0.600000     3.600000   41.500000    0.250000    1.800000
# max       6.200000     9.000000  113.000000    1.200000    6.000000
#
# [8 rows x 30 columns]
# Lasso Predict with transformations
#            0
# 0   0.004489
# 1  -0.200101
# 2   0.089764
# 3   0.000000
# 4  -0.000000
# 5   0.318477
# 6   0.000000
# 7  -0.000000
# 8   0.000000
# 9   0.327150
# 10  0.000000
# 11  0.000000
# 72.6869986486767
#     Actual   Predicted
# 0    17.47   15.710422
# 1    79.08   84.690524
# 2   117.79  107.102549
# 3    78.73   79.622715
# 4    16.07   14.621082
# ..     ...         ...
# 60   83.67   90.713116
# 61   25.13   25.424111
# 62   25.70   23.582588
# 63   81.53   81.792382
# 64   10.40    1.970934
#
# [65 rows x 2 columns]
# Mean Absolute Error: 6.917379460613606
# Mean Squared Error: 84.24386927339519
# Root Mean Squared Error: 9.178445907308884
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.965
# Model:                            OLS   Adj. R-squared (uncentered):              0.963
# Method:                 Least Squares   F-statistic:                              565.7
# Date:                Sat, 12 Oct 2019   Prob (F-statistic):                   1.59e-172
# Time:                        18:42:05   Log-Likelihood:                         -992.42
# No. Observations:                 260   AIC:                                      2009.
# Df Residuals:                     248   BIC:                                      2052.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0494      0.012      4.260      0.000       0.027       0.072
# x2            -0.0578      0.012     -4.673      0.000      -0.082      -0.033
# x3             0.1398      0.028      4.958      0.000       0.084       0.195
# x4            27.3703      3.895      7.027      0.000      19.699      35.042
# x5            -9.7409      4.633     -2.103      0.037     -18.866      -0.616
# x6             0.6744      0.098      6.866      0.000       0.481       0.868
# x7            17.2361      4.536      3.800      0.000       8.301      26.171
# x8             0.7381      2.087      0.354      0.724      -3.373       4.849
# x9             5.5370      1.050      5.273      0.000       3.469       7.605
# x10            0.4203      0.103      4.072      0.000       0.217       0.624
# x11           22.5717      3.876      5.824      0.000      14.938      30.205
# x12            2.8542      2.071      1.378      0.169      -1.224       6.932
# ==============================================================================
# Omnibus:                      128.547   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              718.280
# Skew:                          -1.955   Prob(JB):                    1.07e-156
# Kurtosis:                      10.143   Cond. No.                     2.30e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print("Hello")
# Out:
# Hello
