# %% [markdown]
# # Machine Learning Project: Predicting RB-TE-WR Week 9 Points based on Previous Week Data from 2018 & 2019

# %% [markdown]
# # Kush Gulati

# %% [markdown]
# ## Importing Modules

# %%
#!/usr/bin/env python
# coding: utf-8


#import modules for scikit learn, data frame viewing, etc. 
import math
import io
import pandas as pd  
import numpy as np  
import matplotlib
import matplotlib.pyplot as pp 
import statsmodels.api as sm
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn import linear_model
from statsmodels.api import OLS
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
import scipy.stats
import scipy.optimize
import scipy.spatial
from sklearn import preprocessing
from sklearn.linear_model import ElasticNetCV
import numpy as np
from yellowbrick.regressor import AlphaSelection
import pandas_profiling

# %% [markdown]
# ## Loading in Dataset

# %%
#reads in csv file, data extracted using Scott's scraper
dataset = pd.read_csv('/Users/kushgulati/Desktop/ff_dataWeeklyRBWRTE.csv')
#prints description for our data set
pd.set_option('display.max_columns', 50)

df = pd.DataFrame(dataset)
df.sort_values(by=['l_ppgcurrent'], ascending=False)
# Out:
#                   l_name l_team l_pos  l_proj  l_points1  l_points2  \
# 4    Christian McCaffrey    Car    RB       3      46.20      10.77
# 38           Dalvin Cook    Min    RB      13      26.70      30.87
# 17        Michael Thomas     NO    WR       7      24.20      19.93
# 75          Chris Godwin     TB    WR      70      17.53      29.07
# 3             Mike Evans     TB    WR      21       5.87      11.07
# ..                   ...    ...   ...     ...        ...        ...
# 172        Tommy Sweeney    Buf    TE     929       5.33       0.00
# 193       Donte Moncrief    Pit    WR     133       3.47       0.00
# 208      Anthony Sherman     KC    RB     451       3.00       0.00
# 188           Ryan Grant     GB    WR     246       5.07       0.87
# 184         Josh Bellamy    NYJ    WR     377       3.00       1.33
#
#      l_points3  l_points4  l_points5  l_points6  l_points7  l_points8  \
# 4        29.63  38.030000      53.67     22.830  33.521667      29.23
# 38       27.20  19.830000      29.93     16.970  33.670000      32.67
# 17       20.60  18.330000      48.13     17.930  24.730000      33.57
# 75        8.67  51.470000      38.33     28.070  28.856667      11.87
# 3        51.67  20.930000       0.00     22.400  18.656667      48.20
# ..         ...        ...        ...        ...        ...        ...
# 172       1.20   0.000000       0.00      1.306   0.000000       0.00
# 193       0.00   0.000000       0.00      2.730   1.033333       0.00
# 208       0.00   0.000000       1.20      0.000   2.700000       0.00
# 188       0.00   0.000000       0.00      0.000   0.000000       0.00
# 184       0.00   1.443333       0.00      0.000   0.000000       0.00
#
#      l_points9  l_ppgcurrent  l_pointspg18  l_passydpg18  l_passtdpg18  \
# 4      42.9300     34.090185     28.037500      0.000000             0
# 38     19.1000     26.326667     16.257273      0.000000             0
# 17     25.9275     25.927500     22.604375      0.000000             0
# 75     12.8700     25.192963     13.695625      0.000000             0
# 3      44.0000     24.755185     20.162500      0.000000             0
# ..         ...           ...           ...           ...           ...
# 172     0.0000      0.870667     13.039823      0.015588             0
# 193     0.0000      0.803704      9.014375      0.000000             0
# 208     0.0000      0.766667      1.818750      0.000000             0
# 188     0.0000      0.660000     13.039823      0.015588             0
# 184     0.0000      0.641481     13.039823      0.015588             0
#
#      l_passintpg18  l_rushydpg18  l_rushtdpg18  l_rush1stpg18  l_receptspg18  \
# 4         0.000000    103.000000      1.166667       3.666667       5.833333
# 38        0.000000     61.857143      0.571429       2.857143       2.857143
# 17        0.000000     11.142857      0.000000       0.428571       0.428571
# 75        0.000000     24.500000      0.250000       0.500000       0.750000
# 3         0.000000      0.000000      0.000000       0.000000       1.714286
# ..             ...           ...           ...            ...            ...
# 172       0.001028     14.495392      0.112350       0.708136       2.856013
# 193       0.000000      0.833333      0.000000       0.000000       0.666667
# 208       0.000000      0.285714      0.000000       0.000000       2.857143
# 188       0.001028     14.495392      0.112350       0.708136       2.856013
# 184       0.001028     14.495392      0.112350       0.708136       2.856013
#
#      l_recydspg18  l_rectdpg18  l_rec1stpg18  l_touchdown18    l_ppr18  opp_1  \
# 4       50.833333     0.333333      3.000000       2.250000  34.027778      2
# 38      20.428571     0.000000      1.142857       0.326531   8.163265      2
# 17       2.714286     0.000000      0.142857       0.000000   0.183673      3
# 75       8.500000     0.000000      0.250000       0.062500   0.560000      1
# 3       17.285714     0.142857      1.000000       0.020408   2.938776      1
# ..            ...          ...           ...            ...        ...    ...
# 172     32.269065     0.210393      1.540233       0.196333  11.877894      1
# 193      6.500000     0.000000      0.166667       0.000000   0.444444      2
# 208     48.142857     0.285714      1.857143       0.081633   8.163265      1
# 188     32.269065     0.210393      1.540233       0.196333  11.877894      1
# 184     32.269065     0.210393      1.540233       0.196333  11.877894      1
#
#      opp_2  opp_3  opp_4  opp_5  opp_6  opp_7  opp_8  opp_9  opp_10  opp_11  \
# 4        1      2      2      1      1      0      1    2.0       3       2
# 38       3      2      2      2      1      3      3    3.0       2       2
# 17       2      2      1      3      2      1      3    0.0       3       3
# 75       2      3      2      2      2      0      1    2.0       3       2
# 3        2      3      2      2      2      0      1    2.0       3       2
# ..     ...    ...    ...    ...    ...    ...    ...    ...     ...     ...
# 172      1      1      2      0      2      2      2    2.0       2       2
# 193      3      3      3      2      3      0      1    1.0       1       3
# 208      2      1      3      1      2      2      3    1.0       2       2
# 188      3      1      2      1      3      3      1    2.0       2       0
# 184      2      1      0      2      1      1      2    2.0       3       2
#
#      opp_12  opp_13  opp_14  opp_15  opp_16  opp_17  good_opp  med_opp  \
# 4         1     3.0       2       1       1       1         2        6
# 38        0     1.0       3       2       3       2         6        8
# 17        2     3.0       1       2       1       2         6        6
# 75        3     2.0       2       3       3       3         6        8
# 3         3     2.0       2       3       3       3         6        8
# ..      ...     ...     ...     ...     ...     ...       ...      ...
# 172       2     3.0       1       3       1       1         2        8
# 193       2     2.0       3       2       2       2         6        7
# 208       0     2.0       1       2       2       2         2        9
# 188       1     3.0       2       1       3       3         6        4
# 184       3     1.0       2       2       3       1         3        7
#
#      bad_opp
# 4          8
# 38         2
# 17         4
# 75         2
# 3          2
# ..       ...
# 172        6
# 193        3
# 208        5
# 188        6
# 184        6
#
# [209 rows x 47 columns]

# %% [markdown]
# ## Dropping Missing Values

# %%
dataset=dataset.dropna()
dataset.describe()
# Out:
#             l_proj   l_points1   l_points2   l_points3   l_points4  \
# count   204.000000  204.000000  204.000000  204.000000  204.000000
# mean    198.514706   13.103235    9.825833   10.196667    9.561147
# std     156.794286    9.200734    8.563775   10.331442    9.653742
# min       1.000000    3.000000    0.000000    0.000000    0.000000
# 25%      88.750000    5.802500    1.892500    1.530000    1.322500
# 50%     174.500000   10.835000    8.500000    7.835000    7.200000
# 75%     283.250000   17.225000   15.600000   15.177500   15.250000
# max    1137.000000   46.200000   32.530000   51.670000   51.470000
#
#         l_points5   l_points6   l_points7   l_points8   l_points9  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean    10.154547    9.123951    8.718709   10.261785   10.460382
# std     11.356991    9.508420    9.194926   10.236328    9.965275
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.270000    1.000000    1.151250    1.807500    0.500000
# 50%      7.415000    6.182000    6.530000    8.015000    8.935000
# 75%     14.730000   14.985000   13.747917   15.815000   16.840000
# max     59.470000   49.930000   55.200000   48.200000   50.630000
#
#        l_ppgcurrent  l_pointspg18  l_passydpg18  l_passtdpg18  l_passintpg18  \
# count    204.000000    204.000000    204.000000         204.0     204.000000
# mean      10.247669     13.199021      0.016239           0.0       0.001071
# std        6.379224      5.036452      0.151490           0.0       0.009988
# min        0.641481      1.818750      0.000000           0.0       0.000000
# 25%        5.262063     11.068403      0.000000           0.0       0.000000
# 50%        9.259444     13.039823      0.000000           0.0       0.000000
# 75%       14.038981     14.415565      0.015588           0.0       0.001028
# max       34.090185     30.197857      2.166667           0.0       0.142857
#
#        l_rushydpg18  l_rushtdpg18  l_rush1stpg18  l_receptspg18  l_recydspg18  \
# count    204.000000    204.000000     204.000000     204.000000    204.000000
# mean      14.815658      0.111877       0.718857       2.868945     32.340817
# std       21.889840      0.197006       1.083680       1.558102     20.779222
# min        0.000000      0.000000       0.000000       0.000000      0.000000
# 25%        0.000000      0.000000       0.000000       1.958333     18.553571
# 50%       14.495392      0.112350       0.633333       2.856013     32.269065
# 75%       14.495392      0.112350       0.708136       3.000000     32.380370
# max      103.571429      1.166667       5.166667       8.857143    110.333333
#
#        l_rectdpg18  l_rec1stpg18  l_touchdown18     l_ppr18       opp_1  \
# count   204.000000    204.000000     204.000000  204.000000  204.000000
# mean      0.208046      1.541252       0.198368   11.983685    2.014706
# std       0.198671      1.072183       0.264667   11.717735    0.797026
# min       0.000000      0.000000       0.000000    0.000000    1.000000
# 25%       0.000000      0.825000       0.027778    3.840278    1.000000
# 50%       0.210393      1.540233       0.196333   11.877894    2.000000
# 75%       0.210393      1.571429       0.196333   11.877894    3.000000
# max       1.000000      6.333333       2.250000   78.448980    3.000000
#
#             opp_2       opp_3       opp_4       opp_5       opp_6       opp_7  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     1.985294    2.014706    1.877451    1.838235    1.750000    1.705882
# std      0.765500    0.784568    0.870808    0.914206    0.978211    1.017950
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 50%      2.000000    2.000000    2.000000    2.000000    2.000000    2.000000
# 75%      3.000000    3.000000    3.000000    3.000000    3.000000    3.000000
# max      3.000000    3.000000    3.000000    3.000000    3.000000    3.000000
#
#             opp_8       opp_9      opp_10      opp_11      opp_12      opp_13  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     1.901961    1.686275    1.647059    1.754902    1.740196    1.921569
# std      0.920589    1.012049    1.070399    0.946201    0.960373    0.777596
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 50%      2.000000    2.000000    2.000000    2.000000    2.000000    2.000000
# 75%      3.000000    3.000000    3.000000    3.000000    3.000000    3.000000
# max      3.000000    3.000000    3.000000    3.000000    3.000000    3.000000
#
#            opp_14      opp_15      opp_16      opp_17    good_opp     med_opp  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     1.955882    2.009804    1.941176    1.965686    4.735294    6.240196
# std      0.802100    0.775170    0.760134    0.758401    1.420653    1.555588
# min      1.000000    1.000000    1.000000    1.000000    2.000000    2.000000
# 25%      1.000000    1.000000    1.000000    1.000000    4.000000    5.000000
# 50%      2.000000    2.000000    2.000000    2.000000    5.000000    6.000000
# 75%      3.000000    3.000000    3.000000    3.000000    6.000000    7.250000
# max      3.000000    3.000000    3.000000    3.000000    8.000000   10.000000
#
#           bad_opp
# count  204.000000
# mean     5.024510
# std      1.812487
# min      0.000000
# 25%      4.000000
# 50%      5.000000
# 75%      6.000000
# max     10.000000

# %%
#describes values chosen 
vals = "l_points1,l_points2,l_points3,l_points4,l_points5,l_points6,l_points7,l_points8,l_ppgcurrent,l_pointspg18,l_passydpg18,l_passintpg18,l_rushydpg18,l_rushtdpg18,l_rush1stpg18,l_receptspg18,l_recydspg18,l_rectdpg18,l_rec1stpg18,l_touchdown18,l_ppr18,opp_9"
vals = vals.split(",")

# %% [markdown]
# ## Removing Features w/ Pandas Profiling

# %%
#PANDAS PROFILING

# hold out random portion for test
msk = np.random.rand(len(dataset)) < 0.8
train = dataset[msk]
test = dataset[~msk]
 
#%%
# take a look at the data
profile = train.profile_report()
profile.to_file(output_file='RBTEWRreport.html')

# %%
vals.remove("l_rec1stpg18")
vals.remove("l_rush1stpg18")

# %% [markdown]
# ##  Histogram Visualization

# %%
#predictors
X = dataset[vals].values


#target variable
y = dataset['l_points9'].values

#Plot creation
pp.figure(figsize=(15,10))
pp.tight_layout()

seabornInstance.distplot(dataset['l_points9'])
mean=dataset['l_points9'].mean()
median=dataset['l_points9'].median()

pp.axvline(mean, color='r', linestyle='--')
pp.axvline(median, color='g', linestyle='-')


pp.legend({'Mean':mean,'Median':median})

mmm = pd.DataFrame({'l_points9': ['mean', 'median'], 'Value': [mean, median]})
display(mmm)
# Out:
#   l_points9      Value
# 0      mean  10.460382
# 1    median   8.935000

# %% [markdown]
# ## Split Data Into Training and Test Set

# %%
#splits data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Scale Training and Test Data

# %%
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(X_train)
# Apply transform to both the training set and the test set.
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Ordinary Least Squares Regression (before ElasticNet)

# %%
# Note the difference in argument order
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_train) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.388
# Model:                            OLS   Adj. R-squared (uncentered):              0.302
# Method:                 Least Squares   F-statistic:                              4.533
# Date:                Sat, 23 Nov 2019   Prob (F-statistic):                    3.42e-08
# Time:                        17:56:14   Log-Likelihood:                         -622.09
# No. Observations:                 163   AIC:                                      1284.
# Df Residuals:                     143   BIC:                                      1346.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -6.0175      1.383     -4.350      0.000      -8.752      -3.283
# x2            -4.5966      1.517     -3.031      0.003      -7.594      -1.599
# x3            -5.7661      1.554     -3.710      0.000      -8.838      -2.694
# x4            -5.6705      1.455     -3.898      0.000      -8.546      -2.795
# x5            -6.2988      1.479     -4.259      0.000      -9.222      -3.375
# x6            -6.0303      1.455     -4.143      0.000      -8.907      -3.153
# x7            -4.6702      1.564     -2.987      0.003      -7.761      -1.580
# x8            -5.9778      1.755     -3.405      0.001      -9.448      -2.508
# x9            35.0618      5.125      6.842      0.000      24.932      45.192
# x10            0.5245      1.267      0.414      0.680      -1.981       3.030
# x11            0.2490      1.014      0.246      0.806      -1.754       2.252
# x12           -0.0621      1.055     -0.059      0.953      -2.148       2.024
# x13           -0.6986      1.959     -0.357      0.722      -4.570       3.173
# x14            1.3086      3.437      0.381      0.704      -5.485       8.103
# x15            0.1763      4.318      0.041      0.967      -8.359       8.712
# x16            0.0927      2.686      0.035      0.973      -5.217       5.403
# x17            0.7038      2.872      0.245      0.807      -4.973       6.380
# x18           -1.3324      3.373     -0.395      0.693      -8.001       5.336
# x19           -0.3194      3.578     -0.089      0.929      -7.392       6.754
# x20            0.4934      0.971      0.508      0.612      -1.426       2.412
# ==============================================================================
# Omnibus:                      117.496   Durbin-Watson:                   0.306
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1349.970
# Skew:                          -2.474   Prob(JB):                    7.21e-294
# Kurtosis:                      16.202   Cond. No.                         14.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Elastic Net Cross Validation

# %%
#Cross Validation for Elastic Model
ElasticModel = ElasticNetCV(l1_ratio=0.5, eps=0.001, n_alphas=100, alphas=None, fit_intercept=True, normalize=False, precompute='auto', cv='warn', copy_X=True, verbose=0, n_jobs=None)
ElasticVisualizer = AlphaSelection(ElasticModel)
ElasticVisualizer.fit(X_train, y_train)
ElasticVisualizer.show()

# %% [markdown]
# ## Elastic Net Coefficients, MSE, and Residuals

# %%
#Prints ElasticNet Transformations in Tabular Format 
clf = linear_model.ElasticNet(alpha=.025, fit_intercept=True, normalize=False, precompute=False, copy_X=True, max_iter=1000, tol=0.0001,  selection='cyclic')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)


coefs = pd.DataFrame(clf.coef_, vals)
display(coefs)


print("Intercept: " + str(clf.intercept_))
# Out:
#                        0
# l_points1      -4.030168
# l_points2      -2.505887
# l_points3      -3.385244
# l_points4      -3.549231
# l_points5      -4.242818
# l_points6      -4.042068
# l_points7      -2.458970
# l_points8      -3.158744
# l_ppgcurrent   23.303619
# l_pointspg18    0.599025
# l_passydpg18    0.284556
# l_passintpg18  -0.211128
# l_rushydpg18   -0.818509
# l_rushtdpg18    1.104042
# l_receptspg18   0.008308
# l_recydspg18    0.175498
# l_rectdpg18     0.392396
# l_touchdown18  -1.219764
# l_ppr18        -0.098561
# opp_9           0.699208
# Intercept: 10.179504601226993

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.4783837497598995
# Mean Squared Error: 36.02333264290566
# Root Mean Squared Error: 6.00194407195749

# %%
dfElastic = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

with pd.option_context("display.max_rows", 100):
    display(dfElastic)
# Out:
#       Actual  Predicted
# 0   24.80000  21.500394
# 1   17.60000  12.743713
# 2   20.41250  18.370853
# 3   19.33000  20.443268
# 4    7.67000  12.073660
# 5   10.40000   7.709851
# 6   34.47000  19.165524
# 7    5.40000  10.343100
# 8   28.90000  19.538448
# 9    0.20000   4.785874
# 10  15.13000  18.475822
# 11   0.00000   2.342389
# 12   0.00000   2.419843
# 13   0.00000   6.766590
# 14   0.00000   6.205297
# 15  31.87000  21.399249
# 16   4.93000  16.343582
# 17   4.20000   6.579686
# 18  12.87000  18.330769
# 19  14.30000  15.812764
# 20  17.80000   9.242414
# 21   1.50000   6.696950
# 22  14.77875  13.144341
# 23   3.87000   8.870136
# 24  11.47000  11.176368
# 25   2.53000   1.903708
# 26   0.00000   0.850206
# 27   0.00000   3.644349
# 28   0.00000   4.464659
# 29   9.50000   9.462880
# 30   0.00000   0.557171
# 31  15.13000  18.612237
# 32  26.53000  15.065205
# 33  13.16750  14.224912
# 34  12.60000   8.524022
# 35  22.27000  17.054839
# 36  13.47000  13.189216
# 37   9.33000   9.406431
# 38  42.93000  26.283308
# 39   0.00000   5.502319
# 40   5.30000   5.332300

# %%
print("Elastic Residuals")
dfElastic.plot(kind='bar',figsize=(10,8))
pp.grid(which='major', linestyle='-', linewidth='0.5', color='black')
pp.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
pp.show()
# Out:
# Elastic Graph

# %% [markdown]
# ## Elastic Net Bootstrap (Iterations = 10000)

# %%
import numpy as np
import statistics
from statistics import mean
from statistics import stdev
from sklearn import datasets
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score
from sklearn.utils import resample
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
bootstrap_iter = 10000    # designate the number of iterations for bootstrapping

accuracy = []
coefs = []
intercepts = []

clf = linear_model.ElasticNet(alpha=.025, fit_intercept=True, normalize=False, precompute=False, copy_X=True, max_iter=1000, tol=0.0001,  selection='cyclic')

for i in range(bootstrap_iter):
    X_, y_ = resample(X_train, y_train)
    clf.fit(X_, y_)
    y_pred = clf.predict(X_test)
    acc = metrics.mean_squared_error(y_test, y_pred)
    accuracy.append(acc)
    coefs.append(clf.coef_)
    intercepts.append(clf.intercept_)
    

average = []
for i in range(len(clf.coef_)):
    avg =0
    for j in range(len(coefs)):
        avg += coefs[j][i]
    average.append(avg)


for x in range(len(average)):
    average[x] = average[x]/12


avgs = pd.DataFrame({'Average Coefficients': clf.coef_, 'Values': vals})

display(avgs)
                
print('Average Intercept:', np.mean(intercepts))
# Out:
#     Average Coefficients         Values
# 0              -2.803590      l_points1
# 1              -2.713008      l_points2
# 2              -4.921366      l_points3
# 3              -4.325671      l_points4
# 4              -4.843700      l_points5
# 5              -3.546745      l_points6
# 6              -2.092152      l_points7
# 7              -3.531540      l_points8
# 8              23.617844   l_ppgcurrent
# 9               0.692830   l_pointspg18
# 10              0.626029   l_passydpg18
# 11             -0.117686  l_passintpg18
# 12             -0.114378   l_rushydpg18
# 13              0.298791   l_rushtdpg18
# 14             -1.776978  l_receptspg18
# 15              0.635756   l_recydspg18
# 16              0.800408    l_rectdpg18
# 17             -0.977427  l_touchdown18
# 18              0.720923        l_ppr18
# 19              0.408183          opp_9
# Average Intercept: 10.164748563824903

# %%
MSE = mean(accuracy)
print('Mean Squared Error:', MSE)
print('Root Mean Squared Error:', np.sqrt(MSE))
# Out:
# Mean Squared Error: 41.505123203554604
# Root Mean Squared Error: 6.442446988804378
